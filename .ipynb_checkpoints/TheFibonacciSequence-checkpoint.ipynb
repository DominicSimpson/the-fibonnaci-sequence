# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
# Initialize Fibonacci sequence
fibonacci_first_number = 0
fibonacci_second_number = 1

# Simulate Fibonacci sequence until a given number
fibonacci_limit = 233  # Total spirals (89 + 144)

while fibonacci_first_number + fibonacci_second_number <= fibonacci_limit:
    # Calculate the next Fibonacci number
    fibonacci_new_number = fibonacci_first_number + fibonacci_second_number
    
    # Update the sequence
    fibonacci_first_number = fibonacci_second_number
    fibonacci_second_number = fibonacci_new_number
    
    # Print the current Fibonacci number
    print(f"The new Fibonacci number is {fibonacci_new_number}")
# Out:
# The new Fibonacci number is 1
# The new Fibonacci number is 2
# The new Fibonacci number is 3
# The new Fibonacci number is 5
# The new Fibonacci number is 8
# The new Fibonacci number is 13
# The new Fibonacci number is 21
# The new Fibonacci number is 34
# The new Fibonacci number is 55
# The new Fibonacci number is 89
# The new Fibonacci number is 144
# The new Fibonacci number is 233

# %%
# Generate Fibonacci numbers
def fibonacci(n):
    fib = [0, 1]
    for i in range(2, n):
        fib.append(fib[-1] + fib[-2])
    return fib

# Plot Fibonacci spiral
def fibonacci_spiral(n):
    fib = fibonacci(n)
    plt.figure(figsize=(10, 10))
    angle = 0
    for radius in fib:
        theta = np.linspace(angle, angle + np.pi/2, 100)
        x = radius * np.cos(theta)
        y = radius * np.sin(theta)
        plt.plot(x, y, color='teal')
        angle += np.pi / 2
    plt.axis('equal')
    plt.show()

# Run the function
fibonacci_spiral(10)

# %% [markdown]
# # User
# How can I convert this file into a GitHub repository

# %% [markdown]
# # Assistant
# To convert a file into a GitHub repository, you will need to follow these steps:
#
# 1. **Create a GitHub Account**: If you don't already have one, sign up for a GitHub account at [github.com](https://github.com).
#
# 2. **Install Git**: Make sure you have Git installed on your computer. You can download it from [git-scm.com](https://git-scm.com/).
#
# 3. **Initialize a Local Repository**:
#    - Open your terminal (or command prompt).
#    - Navigate to the directory where your file is located using the `cd` command.
#    - Run the following command to initialize a new Git repository:

# %% [markdown]
# bash
#      git init

# %% [markdown]
# 4. **Add Your File**:
#    - Add your file to the staging area with the following command (replace `yourfile.ext` with the name of your file):

# %% [markdown]
# bash
#      git add yourfile.ext

# %% [markdown]
# 5. **Commit Your Changes**:
#    - Commit the changes with a message:

# %% [markdown]
# bash
#      git commit -m "Initial commit"

# %% [markdown]
# 6. **Create a New Repository on GitHub**:
#    - Go to GitHub and create a new repository. You can do this by clicking the "+" icon in the top right corner and selecting "New repository".
#    - Give your repository a name and click "Create repository".
#
# 7. **Link Your Local Repository to GitHub**:
#    - After creating the repository, GitHub will provide you with a URL. Use this URL to link your local repository to GitHub:

# %% [markdown]
# bash
#      git remote add origin https://github.com/username/repository.git

# %% [markdown]
# 8. **Push Your Changes to GitHub**:
#    - Finally, push your local commits to the GitHub repository:

# %% [markdown]
# bash
#      git push -u origin master

# %% [markdown]
# After completing these steps, your file will be part of a GitHub repository.
#
# If you need to manage your repository or work with multiple files, consider using Python packages like `GitPython` for programmatic access to Git repositories or `PyGithub` for interacting with the GitHub API.

# %%
# Generate Fibonacci spiral points
def sunflower_spiral(n):
    golden_angle = np.pi * (3 - np.sqrt(5))  # Golden angle in radians
    radii = np.sqrt(np.arange(1, n + 1))  # Use square root for gradual spacing
    angles = np.arange(1, n + 1) * golden_angle
    x = radii * np.cos(angles)
    y = radii * np.sin(angles)
    return x, y

# Plot the sunflower spiral
def plot_sunflower(n):
    x, y = sunflower_spiral(n)
    plt.figure(figsize=(10, 10))
    plt.scatter(x, y, c=np.arange(n), cmap='viridis', s=50)
    plt.axis('equal')
    plt.title("Sunflower Pattern (Fibonacci-Based)", fontsize=16)
    plt.show()

# Run the function
plot_sunflower(200)
